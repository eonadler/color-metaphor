# %% [markdown]
# ### Imports

# %%
import numpy as np

# %% [markdown]
# # Main Survey

# %% [markdown]
# ## Color--Term Association Task

# %% [markdown]
# ### Prompt

# %%
terms = {}

terms['extant'] = ['grass','blood','banana','snow']
terms['numbers'] = ['one', 'two', 'three', 'four', 'five']
terms['digits'] = ['1', '2', '3', '4', '5']
terms['disciplines'] = ['psychology', 'chemistry', 'physics', 'math', 'computer science', 'sociology', 'theology', 'philosophy',
              'linguistics', 'history']
terms['emotion'] = ['desire', 'fear', 'shame', 'sadness', 'hate', 'joy', 'anger', 'happiness', 'love', 'affection']

terms['pseudowords'] = ['ackie', 'ambous', 'axittic', 'bombourg', 'boodoma', 'cruckwic', 'gricker', 'heonia', 'horgous', 'keex']
terms['pseudowords_phonesthesia'] = ['glackie', 'snambous', 'glaxittic', 'glombourg', 'blodoma', 'gluckwic', 'twicker', 'gleonia', 'glorgous', 'smeex']

# %%
for key in terms.keys():
    for word in terms[key]:
        for option in ['MOST', 'LEAST']:
            print('Please select the color that {} resembles what this concept brings to mind for you: {}'.format(option,word))
# Out:
# Please select the color that MOST resembles what this concept brings to mind for you: grass
# Please select the color that LEAST resembles what this concept brings to mind for you: grass
# Please select the color that MOST resembles what this concept brings to mind for you: blood
# Please select the color that LEAST resembles what this concept brings to mind for you: blood
# Please select the color that MOST resembles what this concept brings to mind for you: banana
# Please select the color that LEAST resembles what this concept brings to mind for you: banana
# Please select the color that MOST resembles what this concept brings to mind for you: snow
# Please select the color that LEAST resembles what this concept brings to mind for you: snow
# Please select the color that MOST resembles what this concept brings to mind for you: one
# Please select the color that LEAST resembles what this concept brings to mind for you: one
# ...

# %% [markdown]
# ### Answers

# %%
colors = np.array(['blue', 'green', 'orange', 'pink', 'purple', 'red', 'turquoise',
       'white', 'yellow', 'black', 'brown', 'gray'])

# %%
print('Choose from one of the following options: \n')
np.random.shuffle(colors)
for color in colors:
    print(color)
# Out:
# Choose from one of the following options:
#
# red
# brown
# gray
# black
# blue
# green
# yellow
# turquoise
# orange
# white
# pink
# purple

# %% [markdown]
# ## Metaphor Task

# %%
novel_metaphors = ['She was a blue-sleeve worker. – She was ___',
'Their green competition won awards. – The competition was ___',
'Their actions crossed a red border. – Their actions were ___',
'She viewed red. – She felt ___',
'I grew yellow. – I became ___',
'Their prayers were black. – Their prayers were ___',
'It was a black weekend. – The weekend was ___',
'She was famous for her blue opinions. – Her opinions were ___',
'He was having dark blue thoughts. – His thoughts were ___',
'He talked until his face turned white-blue. – He became ___',
'Her style was a mustard yellow journalism. – Her journalism was ___',
'The morning was pale gray. – The morning was ___',
'They were solid green with envy. – They were ___',
'All cities need yellow-green spaces. – All cities need spaces that are ___',
'The joke tickled him sparkling pink. – The joke made him feel ___',
'She was in a soft black mood. – She felt ___',
'Wide eyes are set purple in a thin skull. – The eyes are ___',
'Your eyes search for yellow. – The eyes search for ___',
"Tonight he's in the pink; but soon he'll die. – Tonight, he’s ___",
'What are those blue remembered hills? – The hills are ___',
'A reluctance to accept the black letters in different formations. – The letters are ___',
'Before the gray Depression. – The depression was ___',
'All in green went my love riding. – My love was ___',
'Law lived in a high blue room from which he could see the mountains. – The room was ___']

frozen_metaphors = ['The news came out of the blue. – The news came ___',
'The question is in a gray area. – The question is ___',
'My bank account is in the red. – My bank account is ___',
'The sound was like white noise. – The sound was ___',
"I'm a green recruit. – Relative to the other recruits, I’m ___",
'The purchase was made on the black market. – The purchase was ___',
'They rolled out the red carpet for me. – They treated me ___',
'This is a golden opportunity. – The opportunity is ___']

# %%
for metaphor in novel_metaphors:
    print('Fill in ONE ADJECTIVE to create an expression that best matches the meaning of: {}'.format(metaphor))
# Out:
# Fill in ONE ADJECTIVE to create an expression that best matches the meaning of: She was a blue-sleeve worker. – She was ___
# Fill in ONE ADJECTIVE to create an expression that best matches the meaning of: Their green competition won awards. – The competition was ___
# Fill in ONE ADJECTIVE to create an expression that best matches the meaning of: Their actions crossed a red border. – Their actions were ___
# Fill in ONE ADJECTIVE to create an expression that best matches the meaning of: She viewed red. – She felt ___
# Fill in ONE ADJECTIVE to create an expression that best matches the meaning of: I grew yellow. – I became ___
# Fill in ONE ADJECTIVE to create an expression that best matches the meaning of: Their prayers were black. – Their prayers were ___
# Fill in ONE ADJECTIVE to create an expression that best matches the meaning of: It was a black weekend. – The weekend was ___
# ...

# %%
for metaphor in frozen_metaphors:
    print('Fill in ONE ADJECTIVE to create an expression that best matches the meaning of: {}'.format(metaphor))
# Out:
# Fill in ONE ADJECTIVE to create an expression that best matches the meaning of: The news came out of the blue. – The news came ___
# Fill in ONE ADJECTIVE to create an expression that best matches the meaning of: The question is in a gray area. – The question is ___
# Fill in ONE ADJECTIVE to create an expression that best matches the meaning of: My bank account is in the red. – My bank account is ___
# Fill in ONE ADJECTIVE to create an expression that best matches the meaning of: The sound was like white noise. – The sound was ___
# Fill in ONE ADJECTIVE to create an expression that best matches the meaning of: I'm a green recruit. – Relative to the other recruits, I’m ___
# Fill in ONE ADJECTIVE to create an expression that best matches the meaning of: The purchase was made on the black market. – The purchase was ___
# Fill in ONE ADJECTIVE to create an expression that best matches the meaning of: They rolled out the red carpet for me. – They treated me ___
# ...

# %% [markdown]
# # Follow-up Survey 1

# %% [markdown]
# ## Metaphor Task

# %%
metaphor_prompts = {}
metaphor_answers = {}

metaphor_prompts['teal_death'] = 'She had a teal death. Her death was ___'
metaphor_answers['teal_death'] = ['Peaceful','Unexpected','Violent']

metaphor_prompts['red_death'] = 'She had a red death. Her death was ___'
metaphor_answers['red_death'] = ['Violent','Calm','Prolonged']

metaphor_prompts['pink_idea'] = 'It was a pink idea. The idea was ___'
metaphor_answers['pink_idea'] = ['Exciting','Bad','Confusing']

metaphor_prompts['green_player'] = 'The soccer player was green. They were ___'
metaphor_answers['green_player'] = ['New','Tough','Large']

metaphor_prompts['crimson_day'] = 'He had a crimson day. The day made him feel ___'
metaphor_answers['crimson_day'] = ['Angry','Calm','Slow']

metaphor_prompts['blue_solitude'] = 'Her solitude was blue. The solitude was ___'
metaphor_answers['blue_solitude'] = ['Peaceful','Excruciating','Lucky']

metaphor_prompts['yellow_hike'] = 'The hike was yellow. The hike was ___'
metaphor_answers['yellow_hike'] = ['Tiring','Energizing','Peaceful']

metaphor_prompts['purple_photos'] = 'The photos made him feel purple. He felt ___'
metaphor_answers['purple_photos'] = ['Nostalgic','Alive','Happy']

metaphor_prompts['magenta_date'] = 'She felt magenta after her date.'
metaphor_answers['magenta_date'] = ['She felt confused','She felt enamored','She felt calm']

metaphor_prompts['crimson_meeting'] = 'The meeting made him feel crimson. He felt ___'
metaphor_answers['crimson_meeting'] = ['Enraged','Apologetic','Calm']

metaphor_prompts['teal_meeting'] = 'The meeting made him feel teal. He felt ___'
metaphor_answers['teal_meeting'] = ['Peaceful','Annoyed','Enamored']

metaphor_prompts['burgundy_meeting'] = 'The meeting made him feel burgundy. He felt ___'
metaphor_answers['burgundy_meeting'] = ['Sad','Powerful','Calm']

metaphor_prompts['aqua_death'] = 'She had an aqua death. Her death was ___'
metaphor_answers['aqua_death'] = ['Quick','Painful','Tranquil']

metaphor_prompts['orange_speech'] = 'His speech made me feel orange. I felt ___'
metaphor_answers['orange_speech'] = ['Hopeless','Calm','Energized']

metaphor_prompts['yellow_speech'] = 'His speech made me feel yellow. I felt ___'
metaphor_answers['yellow_speech'] = ['Inspired','Depressed','Calm']

# %%
print('For each sentence, please select the answer that you think best describes its meaning.')
print('\n')

for metaphor in metaphor_prompts:
    print('{}'.format(metaphor_prompts[metaphor]))
    for choice in metaphor_answers[metaphor]:
        print(choice)
    print('\n')
# Out:
# For each sentence, please select the answer that you think best describes its meaning.
#
#
# She had a teal death. Her death was ___
# Peaceful
# Unexpected
# Violent
#
#
# She had a red death. Her death was ___
# Violent
# Calm
# Prolonged
#
#
# It was a pink idea. The idea was ___
# Exciting
# Bad
# Confusing
#
#
# The soccer player was green. They were ___
# New
# Tough
# Large
#
#
# He had a crimson day. The day made him feel ___
# Angry
# Calm
# Slow
#
#
# Her solitude was blue. The solitude was ___
# Peaceful
# Excruciating
# Lucky
#
#
# The hike was yellow. The hike was ___
# Tiring
# Energizing
# Peaceful
#
#
# The photos made him feel purple. He felt ___
# Nostalgic
# Alive
# Happy
#
#
# She felt magenta after her date.
# She felt confused
# She felt enamored
# She felt calm
#
#
# The meeting made him feel crimson. He felt ___
# Enraged
# Apologetic
# Calm
#
#
# The meeting made him feel teal. He felt ___
# Peaceful
# Annoyed
# Enamored
#
#
# ...

# %% [markdown]
# ## Explanation Task

# %%
print('Think of the sentence: "It was a very pink party."')
print('\n')
print("What do you think this means? (feel free to say 'I have no idea' if you do not know)")
print('\n')
print("If you said you didn't know, please try to guess what the phrase might mean or reply NA (not applicable)")
print('\n')
print("How confident are you in your answer, on a scale from 0 to 100?")
print('\n')
print("How did you inform your answer?")
print('\n')
print("Did you use your perception of color to inform your answers?")
print('\n')
print("Do you have any emotional feeling for the word 'pink'? Answer on a scale from 0 to 100.")
print('\n')
print('Which emotions or feelings did this evoke?')
# Out:
# Think of the sentence: "It was a very pink party."
#
#
# What do you think this means? (feel free to say 'I have no idea' if you do not know)
#
#
# If you said you didn't know, please try to guess what the phrase might mean or reply NA (not applicable)
#
#
# How confident are you in your answer, on a scale from 0 to 100?
#
#
# How did you inform your answer?
#
#
# Did you use your perception of color to inform your answers?
#
#
# Do you have any emotional feeling for the word 'pink'? Answer on a scale from 0 to 100.
#
#
# Which emotions or feelings did this evoke?

# %%
print('Think of the sentence: "They were on red alert."')
print('\n')
print("What do you think this means? (feel free to say 'I have no idea' if you do not know)")
print('\n')
print("If you said you didn't know, please try to guess what the phrase might mean or reply NA (not applicable)")
print('\n')
print("How confident are you in your answer, on a scale from 0 to 100?")
print('\n')
print("How did you inform your answer?")
print('\n')
print("Did you use your perception of color to inform your answers?")
print('\n')
print("Do you have any emotional feeling for the word 'red'? Answer on a scale from 0 to 100.")
print('\n')
print('Which emotions or feelings did this evoke?')
# Out:
# Think of the sentence: "They were on red alert."
#
#
# What do you think this means? (feel free to say 'I have no idea' if you do not know)
#
#
# If you said you didn't know, please try to guess what the phrase might mean or reply NA (not applicable)
#
#
# How confident are you in your answer, on a scale from 0 to 100?
#
#
# How did you inform your answer?
#
#
# Did you use your perception of color to inform your answers?
#
#
# Do you have any emotional feeling for the word 'red'? Answer on a scale from 0 to 100.
#
#
# Which emotions or feelings did this evoke?

# %%
words = ['ackie','physics','3','grass']
types = ['pseudoword','word','number','word']

for i,word in enumerate(np.array(words)):
    print('Think of the {}: "{}"'.format(types[i],word))
    print('\n')
    print("What do you think this means? (feel free to say 'I have no idea' if you do not know)")
    print('\n')
    print("What color do you associate with this term? (feel free to say 'I have no idea' if you do not know)")
    print('\n')
    print("If you said you didn't know, please try to guess what color might associate with it")
    print('\n')
    print("How did you inform your answer for the color association?")
    print('\n')
    print("Did you use your perception of color to inform your answers?")
    print('\n')
    print("How confident are you in your answer, on a scale from 0 to 100?")
    print('\n')
    print('Which emotions or feelings did this evoke?')
    print('\n \n')
# Out:
# Think of the pseudoword: "ackie"
#
#
# What do you think this means? (feel free to say 'I have no idea' if you do not know)
#
#
# What color do you associate with this term? (feel free to say 'I have no idea' if you do not know)
#
#
# If you said you didn't know, please try to guess what color might associate with it
#
#
# How did you inform your answer for the color association?
#
#
# Did you use your perception of color to inform your answers?
#
#
# How confident are you in your answer, on a scale from 0 to 100?
#
#
# Which emotions or feelings did this evoke?
#
#
#
# Think of the word: "physics"
#
#
# What do you think this means? (feel free to say 'I have no idea' if you do not know)
#
#
# What color do you associate with this term? (feel free to say 'I have no idea' if you do not know)
#
#
# If you said you didn't know, please try to guess what color might associate with it
#
#
# How did you inform your answer for the color association?
#
#
# ...

# %% [markdown]
# # Follow-up Survey 2

# %% [markdown]
# ## Metaphor Task

# %%
metaphor_prompts = {}
metaphor_answers = {}

metaphor_prompts['teal_death'] = 'She had a teal death.'
metaphor_answers['teal_death'] = ['Her death was peaceful','Her death was unexpected','Her death was violent']

metaphor_prompts['red_death'] = 'She had a red death.'
metaphor_answers['red_death'] = ['Her death was violent','Her death was calm','Her death was prolonged']

metaphor_prompts['pink_idea'] = 'It was a pink idea.'
metaphor_answers['pink_idea'] = ['The idea was exciting','The idea was bad','The idea was confusing']

metaphor_prompts['green_player'] = 'The soccer player was green.'
metaphor_answers['green_player'] = ['They were new','They were tough','They were large']

metaphor_prompts['crimson_day'] = 'He had a crimson day.'
metaphor_answers['crimson_day'] = ['The day made him feel angry','The day made him feel calm','The day made him feel slow']

metaphor_prompts['blue_solitude'] = 'Her solitude was blue.'
metaphor_answers['blue_solitude'] = ['The solitude was peaceful','The solitude was excruciating','The solitude was lucky']

metaphor_prompts['yellow_hike'] = 'The hike was yellow.'
metaphor_answers['yellow_hike'] = ['The hike was tiring','The hike was energizing','The hike was peaceful']

metaphor_prompts['purple_photos'] = 'The photos made him feel purple.'
metaphor_answers['purple_photos'] = ['He felt nostalgic','He felt alive','He felt happy']

metaphor_prompts['magenta_date'] = 'She felt magenta after her date.'
metaphor_answers['magenta_date'] = ['She felt confused','She felt enamored','She felt calm']

metaphor_prompts['crimson_meeting'] = 'The meeting made him feel crimson.'
metaphor_answers['crimson_meeting'] = ['He felt enraged','He felt apologetic','He felt calm']

metaphor_prompts['teal_meeting'] = 'The meeting made him feel teal.'
metaphor_answers['teal_meeting'] = ['He felt peaceful','He felt annoyed','He felt enamored']

metaphor_prompts['burgundy_meeting'] = 'The meeting made him feel burgundy.'
metaphor_answers['burgundy_meeting'] = ['He felt sad','He felt powerful','He felt calm']

metaphor_prompts['aqua_death'] = 'She had an aqua death.'
metaphor_answers['aqua_death'] = ['Her death was quick','Her death was painful','Her death was tranquil']

metaphor_prompts['orange_speech'] = 'His speech made me feel orange.'
metaphor_answers['orange_speech'] = ['I felt hopeless','I felt calm','I felt energized']

metaphor_prompts['yellow_speech'] = 'His speech made me feel yellow.'
metaphor_answers['yellow_speech'] = ['I felt inspired','I felt depressed','I felt calm']

# %%
print('Please select the answer that best describes the METAPHORICAL meaning of each sentence.')
print('\n')

for metaphor in metaphor_prompts:
    print('{}'.format(metaphor_prompts[metaphor]))
    for choice in metaphor_answers[metaphor]:
        print(choice)
    print('\n')
# Out:
# Please select the answer that best describes the METAPHORICAL meaning of each sentence.
#
#
# She had a teal death.
# Her death was peaceful
# Her death was unexpected
# Her death was violent
#
#
# She had a red death.
# Her death was violent
# Her death was calm
# Her death was prolonged
#
#
# It was a pink idea.
# The idea was exciting
# The idea was bad
# The idea was confusing
#
#
# The soccer player was green.
# They were new
# They were tough
# They were large
#
#
# He had a crimson day.
# The day made him feel angry
# The day made him feel calm
# The day made him feel slow
#
#
# Her solitude was blue.
# The solitude was peaceful
# The solitude was excruciating
# The solitude was lucky
#
#
# The hike was yellow.
# The hike was tiring
# The hike was energizing
# The hike was peaceful
#
#
# The photos made him feel purple.
# He felt nostalgic
# He felt alive
# He felt happy
#
#
# She felt magenta after her date.
# She felt confused
# She felt enamored
# She felt calm
#
#
# ...

# %%
metaphor_prompts = {}
metaphor_answers = {}

metaphor_prompts['blue_news'] = 'The news came out of the blue.'
metaphor_answers['blue_news'] = ['The news came unexpectedly','The news came slowly','The news came humorously']

metaphor_prompts['gray_area'] = 'The question is in a gray area.'
metaphor_answers['gray_area'] = ['The question is clear','The question is ambiguous','The question is moving']

metaphor_prompts['red_account'] = 'My bank account is in the red.'
metaphor_answers['red_account'] = ['My bank account is private','My bank account is empty','My bank account is new']

metaphor_prompts['white_noise'] = 'The sound was like white noise'
metaphor_answers['white_noise'] = ['The sound was sweet','The sound was loud','The sound was like static']

metaphor_prompts['green_recruit'] = "I'm a green recruit."
metaphor_answers['green_recruit'] = ["I'm strong","I'm unexperienced","I'm musical"]

metaphor_prompts['black_market'] = 'The purchase was made on the black market.'
metaphor_answers['black_market'] = ['The purchase was swift','The purchase was illegal','The purchase was important']

metaphor_prompts['red_carpet'] = 'They rolled out the red carpet for me.'
metaphor_answers['red_carpet'] = ['They treated me royally','They treated me comically','They treated me savagely']

metaphor_prompts['golden_opportunity'] = 'This is a golden opportunity.'
metaphor_answers['golden_opportunity'] = ['The opportunity is rare','The opportunity is difficult','The opportunity is unpredictable']

# %%
print('Please select the answer that best describes the METAPHORICAL meaning of each sentence.')
print('\n')

for metaphor in metaphor_prompts:
    print('{}'.format(metaphor_prompts[metaphor]))
    for choice in metaphor_answers[metaphor]:
        print(choice)
    print('\n')
# Out:
# Please select the answer that best describes the METAPHORICAL meaning of each sentence.
#
#
# The news came out of the blue.
# The news came unexpectedly
# The news came slowly
# The news came humorously
#
#
# The question is in a gray area.
# The question is clear
# The question is ambiguous
# The question is moving
#
#
# My bank account is in the red.
# My bank account is private
# My bank account is empty
# My bank account is new
#
#
# The sound was like white noise
# The sound was sweet
# The sound was loud
# The sound was like static
#
#
# I'm a green recruit.
# I'm strong
# I'm unexperienced
# I'm musical
#
#
# The purchase was made on the black market.
# The purchase was swift
# The purchase was illegal
# The purchase was important
#
#
# They rolled out the red carpet for me.
# They treated me royally
# They treated me comically
# They treated me savagely
#
#
# This is a golden opportunity.
# The opportunity is rare
# The opportunity is difficult
# ...

# %%
metaphor_prompts = {}
metaphor_answers = {}

metaphor_prompts['thorny_bush'] = 'He was poking around a thorny bush.'
metaphor_answers['thorny_bush'] = ['He was looking for clues in a delicate situation','He was looking for something he had lost','He was walking around a garden']

metaphor_prompts['squeeze_juice'] = 'He was trying to squeeze orange juice out of an apple.'
metaphor_answers['squeeze_juice'] = ['He was trying to do something very difficult and unordinary','He was trying to audition for a cooking show','He was trying to win a math competition']

metaphor_prompts['frosting_fingers'] = 'Keep your fingers out of my frosting.'
metaphor_answers['frosting_fingers'] = ['Stay away from my business',"Don't read my book",'We have the same interests']

metaphor_prompts['sprinkled_cheer'] = 'They sprinkled him with cheer.'
metaphor_answers['sprinkled_cheer'] = ['They were all very affectionate of him','They had a fundraiser','They were shy']

metaphor_prompts['pointed_fingers'] = 'All fingers pointed in the same direction.'
metaphor_answers['pointed_fingers'] = ['The accusations all point to one person','Everyone is hungry','Everyone should be on the same team']

metaphor_prompts['twisted_brain'] = 'I am twisting my brain into knots over this.'
metaphor_answers['twisted_brain'] = ['I am trying in every way to understand it','I have a headache',"I'm analyzing my brain"]

metaphor_prompts['caverns_heart'] = 'He took a long walk around the caverns of his own heart.'
metaphor_answers['caverns_heart'] = ['He thought carefully about his feelings','He underwent heart surgery','He took a long walk and got lost']

metaphor_prompts['tack_foot'] = 'He is a real tack in my foot.'
metaphor_answers['tack_foot'] = ["He is someone I don't like at all",'He is someone I want to invite for coffee','He is someone I want to kick a ball with']

metaphor_prompts['kick_back'] = 'He was trying to kick back up an old look.'
metaphor_answers['kick_back'] = ['He was trying to revive a clothing style from a previous time period','He looked too mature','He was playing soccer']

metaphor_prompts['toe_stubbed'] = 'She was the first toe to get stubbed.'
metaphor_answers['toe_stubbed'] = ['She was commonly the first to have a bad experience','She had the wrong shoes','She wore clothes from another century']

metaphor_prompts['icy_slope'] = 'She was skiing along an icy slope.'
metaphor_answers['icy_slope'] = ['She was in a delicate and unstable situation','She enjoys sports','She is lonely']

metaphor_prompts['score_kicked'] = 'He score-kicked that closing statement in the trial.'
metaphor_answers['score_kicked'] = ['He brilliantly argued his closing statement','He got angry after listening to the statement','He kicked a ball after listening to the statement']

# %%
print('Please select the answer that best describes the METAPHORICAL meaning of each sentence.')
print('\n')

for metaphor in metaphor_prompts:
    print('{}'.format(metaphor_prompts[metaphor]))
    for choice in metaphor_answers[metaphor]:
        print(choice)
    print('\n')
# Out:
# Please select the answer that best describes the METAPHORICAL meaning of each sentence.
#
#
# He was poking around a thorny bush.
# He was looking for clues in a delicate situation
# He was looking for something he had lost
# He was walking around a garden
#
#
# He was trying to squeeze orange juice out of an apple.
# He was trying to do something very difficult and unordinary
# He was trying to audition for a cooking show
# He was trying to win a math competition
#
#
# Keep your fingers out of my frosting.
# Stay away from my business
# Don't read my book
# We have the same interests
#
#
# They sprinkled him with cheer.
# They were all very affectionate of him
# They had a fundraiser
# They were shy
#
#
# All fingers pointed in the same direction.
# The accusations all point to one person
# Everyone is hungry
# Everyone should be on the same team
#
#
# I am twisting my brain into knots over this.
# I am trying in every way to understand it
# I have a headache
# ...

# %%
metaphor_prompts = {}
metaphor_answers = {}

metaphor_prompts['revealed_hand'] = 'He revealed his hand.'
metaphor_answers['revealed_hand'] = ['He made his secret plans and intentions known','He raised his hands into the air','He asked for charity']

metaphor_prompts['catch_name'] = 'I did not catch your name.'
metaphor_answers['catch_name'] = ['I would like you to repeat your name','I caught the baseball','I do not like you']

metaphor_prompts['fingers_crossed'] = 'Keep your fingers crossed.'
metaphor_answers['fingers_crossed'] = ['Hope strongly that it will happen','Hold something in place',"Don't move your fingers"]

metaphor_prompts['knock_wood'] = 'Knock on wood.'
metaphor_answers['knock_wood'] = ["To hope for one's good luck to continue",'To knock on the door','To ring a doorbell']

metaphor_prompts['clock_spun'] = 'The hands of the clock spun.'
metaphor_answers['clock_spun'] = ['The time is passing quickly','The clock was an hour ahead','The clock is working properly']

metaphor_prompts['hand_point'] = 'On the other hand, he has got a point.'
metaphor_answers['hand_point'] = ['He is right','He has a tack in his foot','He scored big']

metaphor_prompts['cold_feet'] = 'The bride got cold feet.'
metaphor_answers['cold_feet'] = ['The bride was too fearful to go on with the marriage','The church had no heating','The groom was without shoes']

metaphor_prompts['run_through'] = 'They did a quick run through.'
metaphor_answers['run_through'] = ['They quickly went through the steps','They crossed the road','They met each other by accident']

metaphor_prompts['nose_running'] = 'His nose was running.'
metaphor_answers['nose_running'] = ['He had mucus flowing from his nose','His nose had legs','He had pain in his nose']

metaphor_prompts['kicked_bucket'] = 'He kicked the bucket.'
metaphor_answers['kicked_bucket'] = ['He died','He gave up','He ran a race poorly']

metaphor_prompts['last_legs'] = 'The family pet was on its last legs.'
metaphor_answers['last_legs'] = ['The pet was in a very bad condition','The pet was able to walk','The pet gave the family one last chance']

metaphor_prompts['leg_up'] = 'The hare had a leg up on the tortoise.'
metaphor_answers['leg_up'] = ['The hare had an advantage over the tortoise','The hare climbed on top of the stone','The hare kicked the tortoise']

# %%
print('Please select the answer that best describes the METAPHORICAL meaning of each sentence.')
print('\n')

for metaphor in metaphor_prompts:
    print('{}'.format(metaphor_prompts[metaphor]))
    for choice in metaphor_answers[metaphor]:
        print(choice)
    print('\n')
# Out:
# Please select the answer that best describes the METAPHORICAL meaning of each sentence.
#
#
# He revealed his hand.
# He made his secret plans and intentions known
# He raised his hands into the air
# He asked for charity
#
#
# I did not catch your name.
# I would like you to repeat your name
# I caught the baseball
# I do not like you
#
#
# Keep your fingers crossed.
# Hope strongly that it will happen
# Hold something in place
# Don't move your fingers
#
#
# Knock on wood.
# To hope for one's good luck to continue
# To knock on the door
# To ring a doorbell
#
#
# The hands of the clock spun.
# The time is passing quickly
# The clock was an hour ahead
# The clock is working properly
#
#
# On the other hand, he has got a point.
# He is right
# He has a tack in his foot
# He scored big
#
#
# The bride got cold feet.
# The bride was too fearful to go on with the marriage
# The church had no heating
# The groom was without shoes
#
#
# They did a quick run through.
# ...
